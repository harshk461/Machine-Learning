# %%
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as sns
from sklearn.datasets import load_diabetes  
from sklearn.linear_model import LinearRegression  
from sklearn.model_selection import train_test_split  
from sklearn.metrics import mean_squared_error, r2_score

# %%
#load dataset
X,Y=load_diabetes(return_X_y=True)

# %%
# Taking only one feature to perform simple linear regression  
X = X[:,8].reshape(-1,1)

# %%
X_train, X_test, Y_train, Y_test = train_test_split( X, Y, test_size = 0.3, random_state = 10 )

# %%
model=LinearRegression()  
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred=model.predict(X_test)

# %%
plt.scatter(X_test,Y_test,label='Original Data')

# %%
plt.scatter(X_test, Y_test, color = "black", label = "original data")  
plt.plot(X_test, Y_pred, color = "blue", linewidth=3, label = "regression line")  
plt.xlabel("Independent Feature")  
plt.ylabel("Target Values")  
plt.title("Simple Linear Regression")  
plt.show()

# %%
Y_pred,Y_test
# Out:
# (array([174.31681864, 190.75328535, 185.97162262,  88.86954344,
#         165.27237144,  98.27321404, 131.61712927, 180.88661568,
#         120.12198013, 113.07321855, 134.49091655, 224.34466559,
#         127.62575804, 134.49091655,  65.9031934 , 149.81778206,
#         142.52155545, 132.5830411 , 134.49091655, 101.1789323 ,
#         187.43246449, 170.22167176,  95.2557374 , 169.62296608,
#          72.29737011, 158.61476424, 176.56795201, 163.98714991,
#         182.96212872, 123.42683551, 224.34466559, 102.59187771,
#         105.33794111, 163.98714991, 179.82491093, 182.44325046,
#          90.51398838, 120.12198013, 182.44325046, 170.82037745,
#         173.75004393, 165.91099084, 187.91941178, 145.02813658,
#          98.27321404,  93.70708536, 118.98843071, 140.80526583,
#         237.26074287, 109.29738137, 171.41908313, 152.10882914,
#         134.49091655, 173.17528647, 211.83570816,  85.46889515,
#         116.6734354 , 142.52155545, 182.96212872, 118.98843071,
#         174.8915761 , 123.42683551, 137.25294544,  95.2557374 ,
#         113.07321855, 155.78887341, 139.9351469 , 127.62575804,
#         187.91941178, 129.64539188, 194.38543316, 203.98068959,
#          65.9031934 ,  95.2557374 , 216.68123283, 182.96212872,
#         172.59254627, 177.66957047, 123.42683551, 173.75004393,
#         129.64539188, 145.02813658, 179.82491093, 145.85035906,
#         165.27237144, 150.59210807, 165.91099084,  96.78044121,
#         123.42683551, 146.65661604, 124.496523  , 131.61712927,
#         129.64539188, 180.88661568, 126.59598426, 126.59598426,
#          80.08852674, 160.67431179, 121.23956408,  90.51398838,
#         115.49198951, 164.63375205, 189.81930448, 178.75522344,
#         115.49198951, 159.30926283, 123.42683551, 152.85920693,
#         127.62575804,  74.31700395, 163.33256503, 163.33256503,
#         130.63525194, 157.92026564,  68.09046483, 171.41908313,
#         190.29028629, 109.29738137, 134.49091655, 189.34832268,
#         179.82491093, 267.17207884,  99.73405591, 133.5409702 ,
#         127.62575804, 136.3429128 , 191.21628441, 130.63525194,
#          39.92734946, 115.49198951, 140.80526583, 124.496523  ,
#         200.77162713]),
#  array([200., 202.,  67.,  80., 151., 145.,  65., 308.,  42.,  92., 150.,
#         202., 184., 101.,  47., 237.,  88., 152., 109.,  89., 163., 274.,
#         138., 275.,  63., 154., 131.,  91., 128., 129., 243., 200.,  72.,
#         185., 296., 144.,  75., 175., 281., 292., 292., 214., 275.,  92.,
#          65.,  31.,  53.,  51., 258.,  40.,  69.,  86., 142., 128., 243.,
#          55., 144., 230., 265.,  63., 217., 102.,  66., 101., 137., 261.,
#         147.,  64., 252.,  59., 220., 126.,  43.,  48., 217., 164., 143.,
#         206.,  72., 110., 244.,  51.,  52., 302., 276., 150., 124., 114.,
#         179.,  91., 257.,  84., 131., 150., 293., 127.,  39.,  83., 191.,
#          65.,  65., 265., 242., 219.,  69., 178., 170., 279.,  83.,  45.,
#         178., 174., 214., 202.,  99.,  94., 235., 158.,  59., 220., 275.,
#         242., 113.,  71.,  81.,  85., 297., 253., 104.,  77.,  53.,  91.,
#         283.]))

# %%
plt.scatter(X_test,Y_test)
plt.scatter(X_test,Y_pred)
